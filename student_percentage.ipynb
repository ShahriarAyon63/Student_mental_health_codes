# %%
import pandas as pd
import numpy as np

import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Assuming your file is in Excel format, use read_excel
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Depression_student.csv')
data.head()
# Out:
#   1. Age 2. Gender                             3. University  \
# 0  18-22    Female  Independent University, Bangladesh (IUB)
# 1  18-22      Male  Independent University, Bangladesh (IUB)
# 2  18-22      Male  Independent University, Bangladesh (IUB)
# 3  18-22      Male  Independent University, Bangladesh (IUB)
# 4  18-22      Male  Independent University, Bangladesh (IUB)
#
#                                   4. Department           5. Academic Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Fourth Year or Equivalent
# 1  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 2  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 3  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 4  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
#
#   6. Current CGPA  Unnamed: 6  \
# 0     2.50 - 2.99         NaN
# 1     3.80 - 4.00         NaN
# 2     3.00 - 3.39         NaN
# ...

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Depression_student.csv')

# Calculate the percentage of each category
age_percentage = data['1. Age'].value_counts(normalize=True) * 100

# Display the results
print(age_percentage)
# Out:
# 1. Age
# 18-22       64.390491
# 23-26       34.041477
# 27-30        1.213961
# Below 18     0.202327
# Above 30     0.151745
# Name: proportion, dtype: float64

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Depression_student.csv')

# Calculate the percentage of each category
gender_percentage = data['2. Gender'].value_counts(normalize=True) * 100

# Display the results
print(gender_percentage)
# Out:
# 2. Gender
# Male                 69.398078
# Female               30.096105
# Prefer not to say     0.505817
# Name: proportion, dtype: float64

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Depression_student.csv')

# Calculate the percentage of each category
depression_percentage = data['Depression Level:\n1-4 Minimal depression\n5-9 Mild depression\n10-14 Moderate depression\n15-19 Moderately severe depression\n20-27 Severe depression'].value_counts(normalize=True) * 100

# Display the results
print(depression_percentage)
# Out:
# Depression Level:\n1-4 Minimal depression\n5-9 Mild depression\n10-14 Moderate depression\n15-19 Moderately severe depression\n20-27 Severe depression
# Moderately Severe Depression    25.037936
# Severe Depression               24.683864
# Moderate Depression             22.711179
# Mild Depression                 20.637329
# Minimal Depression               4.704097
# No Depression                    2.225594
# Name: proportion, dtype: float64

# %%
import pandas as pd

# Assuming your file is in Excel format, use read_excel
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Stress.csv')
data.head()
# Out:
#   1. Age 2. Gender                             3. University  \
# 0  18-22    Female  Independent University, Bangladesh (IUB)
# 1  18-22      Male  Independent University, Bangladesh (IUB)
# 2  18-22      Male  Independent University, Bangladesh (IUB)
# 3  18-22      Male  Independent University, Bangladesh (IUB)
# 4  18-22      Male  Independent University, Bangladesh (IUB)
#
#                                   4. Department           5. Academic Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Fourth Year or Equivalent
# 1  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 2  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 3  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 4  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
#
#   6. Current CGPA  \
# 0     2.50 - 2.99
# 1     3.80 - 4.00
# 2     3.00 - 3.39
# 3     3.40 - 3.79
# 4     3.40 - 3.79
#
# ...

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Stress.csv')

# Calculate the percentage of each category
age_percentage = data['1. Age'].value_counts(normalize=True) * 100

# Display the results
print(age_percentage)
# Out:
# 1. Age
# 18-22       64.390491
# 23-26       34.041477
# 27-30        1.213961
# Below 18     0.202327
# Above 30     0.151745
# Name: proportion, dtype: float64

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Stress.csv')

# Calculate the percentage of each category
gender_percentage = data['2. Gender'].value_counts(normalize=True) * 100

# Display the results
print(gender_percentage)
# Out:
# 2. Gender
# Male                 69.398078
# Female               30.096105
# Prefer not to say     0.505817
# Name: proportion, dtype: float64

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Stress.csv')

# Calculate the percentage of each category
stress_percentage = data['Stress Level\n0-13: low stress\n14-26: moderate stress\n27-40: high preceived stress'].value_counts(normalize=True) * 100

# Display the results
print(stress_percentage)
# Out:
# Stress Level\n0-13: low stress\n14-26: moderate stress\n27-40: high preceived stress
# Moderate Stress          66.565503
# High Perceived Stress    27.617602
# Low Stress                5.816894
# Name: proportion, dtype: float64

# %%
import pandas as pd

# Specify the encoding when reading the CSV file
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Anxiety.csv', encoding='latin1')

# Display the first few rows of the DataFrame
data.head()
# Out:
#   1. Age 2. Gender                             3. University  \
# 0  18-22    Female  Independent University, Bangladesh (IUB)
# 1  18-22      Male  Independent University, Bangladesh (IUB)
# 2  18-22      Male  Independent University, Bangladesh (IUB)
# 3  18-22      Male  Independent University, Bangladesh (IUB)
# 4  18-22      Male  Independent University, Bangladesh (IUB)
#
#                                   4. Department           5. Academic Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Fourth Year or Equivalent
# 1  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 2  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 3  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
# 4  Engineering - CS / CSE / CSC / Similar to CS   First Year or Equivalent
#
#   6. Current CGPA  \
# 0     2.50 - 2.99
# 1     3.80 - 4.00
# 2     3.00 - 3.39
# 3     3.40 - 3.79
# 4     3.40 - 3.79
#
# ...

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Anxiety.csv', encoding='latin1')

# Calculate the percentage of each category
age_percentage = data['1. Age'].value_counts(normalize=True) * 100

# Display the results
print(age_percentage)
# Out:
# 1. Age
# 18-22       64.390491
# 23-26       34.041477
# 27-30        1.213961
# Below 18     0.202327
# Above 30     0.151745
# Name: proportion, dtype: float64

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Anxiety.csv', encoding='latin1')

# Calculate the percentage of each category
gender_percentage = data['2. Gender'].value_counts(normalize=True) * 100

# Display the results
print(gender_percentage)
# Out:
# 2. Gender
# Male                 69.398078
# Female               30.096105
# Prefer not to say     0.505817
# Name: proportion, dtype: float64

# %%
# Read the dataset
data = pd.read_csv('/content/drive/MyDrive/bangladesh_student/Anxiety.csv', encoding='latin1')

# Calculate the percentage of each category
anxiety_percentage = data['Anxiety Level\n04: minimal anxiety\n59: mild anxiety\n1014: moderate anxiety\n1521: severe anxiety'].value_counts(normalize=True) * 100

# Display the results
print(anxiety_percentage)
# Out:
# Anxiety Level\n04: minimal anxiety\n59: mild anxiety\n1014: moderate anxiety\n1521: severe anxiety
# Severe Anxiety      36.115326
# Moderate Anxiety    30.854831
# Mild Anxiety        25.037936
# Minimal Anxiety      7.991907
# Name: proportion, dtype: float64
